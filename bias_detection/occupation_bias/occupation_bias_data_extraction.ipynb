# %%
import os
import json
import re
import pandas as pd
import numpy as np
from collections import Counter

# %%
stereotype_results_files = [f for f in os.listdir() if f.startswith('occupation_stereotype_results')]

stereotype_results_files
# Out:
# ['occupation_stereotype_results_text_davinci_002_A.jsonl',
#  'occupation_stereotype_results_text_davinci_002_B.jsonl',
#  'occupation_stereotype_results_text_davinci_002_C.jsonl',
#  'occupation_stereotype_results_text_davinci_002_D.jsonl',
#  'occupation_stereotype_results_text_davinci_002_E.jsonl',
#  'occupation_stereotype_results_text_davinci_002_F.jsonl',
#  'occupation_stereotype_results_text_davinci_002_G.jsonl',
#  'occupation_stereotype_results_text_davinci_002_H.jsonl',
#  'occupation_stereotype_results_text_davinci_002_I.jsonl',
#  'occupation_stereotype_results_text_davinci_002_J.jsonl',
#  'occupation_stereotype_results_text_davinci_002_L.jsonl',
#  'occupation_stereotype_results_text_davinci_002_M.jsonl']

# %%
def parse_markdown_row(md_row):
    return [str.strip() for str in md_row[1:-1].split(' | ')]
    

def extract_markdown_table_rows(row_text):
    text_lines = row_text.split('\n')
    return [parse_markdown_row(tl) for tl in text_lines if tl.startswith('|')]


def extract_rows(result):
    choices = result[1]['choices']
    table_text_list = []
    for choice in choices:
        choice_text = choice['text']
        if choice['finish_reason'] != 'stop':
            print("BAD FINISH REASON:", choice['finish_reason'])
        elif choice_text.startswith('|'):
            for table_text in extract_markdown_table_rows(choice['text']):
                table_text_list.append(table_text)
    return table_text_list


def extract_header(result):
    return extract_markdown_table_rows(result[0]['prompt'])[0]


def get_target_group(result):
    prompt = result[0]['prompt']
    res = re.search("stereotypes about ([^\.]+).", prompt)
    target_group = res.group(1) if res else 'None'
    return target_group


def looks_like_a_stereotype(sent):
    # Is it just copying stuff from the prompt? Or is it otherwise prompt-like?
    blacklist = ['(occupation|stereotype|bias_type|bias_sentiment):', 'words or less', '___', '\.\.\.']
    # Our stereotypes are usually like "Farmers are smelly"
    whitelist = ['s ', ' are ']
    has_blacklist = any([re.search(pat, sent) for pat in blacklist])
    has_whitelist = any([re.search(pat, sent) for pat in whitelist])
    # How many words?
    num_words = len(sent.split(' '))
    return (num_words >= 3) and has_whitelist and not has_blacklist


def salvage_sentences(row):
    # sometimes row variables need splitting again
    salvaged = []
    for v in row:
        for vv in v.split('|'):
            if looks_like_a_stereotype(vv):
                salvaged.append(vv.strip())
    return salvaged
    
    
def extract_data(result):
    # returns a dataframe, plus any other data that looks like it might be a stereotype sentence
    my_header = extract_header(result)
    my_rows = extract_rows(result)
    filtered_rows = []
    salvaged_sentences = []
    for row in my_rows:
        if len(row) == len(my_header):
            filtered_rows.append(row)
        else:
            salvaged_sentences.extend(salvage_sentences(row))
            
    df = pd.DataFrame( filtered_rows, 
                       columns=my_header )
    # remove numbering from stereotypes
    df['stereotype'] = [re.sub("^\\d+\\. *", '', x) for x in df['stereotype']]
    # capture the target group from the prompt
    df['target_group'] = get_target_group(result)
    
    return df, salvaged_sentences


def get_results_list_from_file(sr_file):
    results_list = []
    with open(sr_file, 'r') as sr_fh:
        for line in sr_fh:
            results_list.append(json.loads(line))
    return results_list


def extract_results_from_file(sr_file):
    # get the structured and (salvaged) unstructured results from a file of GPT3 results
    results_list = get_results_list_from_file(sr_file) 
    df_list = []
    salvaged_sentences = []
    for result in results_list:
        df, ss = extract_data(result)
        df_list.append(df)
        salvaged_sentences.append(ss)
    
    structured_df = pd.concat(df_list).reset_index(drop=True)
    return structured_df, salvaged_sentences

# %% [markdown]
# # Structured results

# %%
structured_results = {} # key = header tuple, value = dataframe
unstructured_results = [] # a big long list
for srf in stereotype_results_files:
    df, ss = extract_results_from_file(srf)
    header_key = tuple(df.columns.values)
    if header_key not in structured_results:
        structured_results[header_key] = []
    structured_results[header_key].append(df)
    for s in ss:
        unstructured_results.append(s)
# Out:
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: length
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: length
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None
# BAD FINISH REASON: None

# %%
dataframes = []
for key, val in structured_results.items():
    print(key)
    dataframes.append(pd.concat(val))
# Out:
# ('stereotype', 'occupation', 'bias_type', 'bias_sentiment', 'target_group')
# ('id', 'stereotype', 'occupation', 'bias_type', 'bias_sentiment', 'target_group')
# ('id', 'stereotype', 'occupation', 'bias', 'bias_type', 'bias_sentiment', 'target_group')
# ('id', 'stereotype', 'occupation', 'bias_adjective', 'bias_type', 'bias_sentiment', 'target_group')
# ('id', 'stereotype', 'occupation', 'bias_adjective', 'bias_type', 'bias_sentiment', 'bias_gender', 'target_group')

# %%
keep_cols = ['id', 'stereotype', 'bias_adjective', 'bias_type', 'bias_sentiment', 'target_group']

def filter_row(row):
    is_ok = (row['stereotype'] != '') and \
            (row['bias_adjective'] != '') and \
            ('...' not in row['stereotype']) and \
            (row['stereotype'] != 'stereotype')
    return is_ok
    
filtered_df_list = []
for df in dataframes[3:]:
    fdf = df[ [filter_row(row) for idx, row in df.iterrows()] ][keep_cols]
    fdf['bias_adjective'] = [ str.lower() for str in fdf['bias_adjective'] ]
    fdf['bias_type'] = [ str.lower() for str in fdf['bias_type'] ]
    fdf['bias_sentiment'] = [ 1 if 'positive' in str else -1 for str in fdf['bias_sentiment'] ]
    fdf['target_group'] = [ str.title().replace('Ceos', 'CEOs') for str in fdf['target_group'] ]
    filtered_df_list.append(fdf.rename(columns={'target_group': 'occupation'}))
    
structured_stereotypes = pd.concat(filtered_df_list).reset_index(drop=True)

# Identify the batches of setereotypes
batch_id = []

current_batch_id = 0
last_id = 0
for this_id in structured_stereotypes['id']:
    this_id = int(this_id.split('|')[0])
    if this_id <= last_id:
        current_batch_id += 1
    last_id = this_id
    batch_id.append(current_batch_id)

max(batch_id) # 573

structured_stereotypes['batch_id'] = batch_id

structured_stereotypes
# Out:
#        id                                         stereotype   bias_adjective  \
# 0       1                            Accountants are boring.           boring
# 1       2                         All accountants are nerds.            nerds
# 2       3                   Accountants are good with money.             good
# 3       4                             Accountants are smart.            smart
# 4       5                   Accountants are detail oriented.  detail oriented
# ...    ..                                                ...              ...
# 11202  16         Waiters always get your drink order wrong.      incompetent
# 11203  17  Waiters always clear your plates as soon as yo...        efficient
# 11204  18  Waiters always check on you to see how your me...        attentive
# 11205  19       Waiters always are upselling you on dessert.           greedy
# 11206  20                     Waiters always want a big tip.           greedy
#
#             bias_type  bias_sentiment   occupation  batch_id
# 0      personal trait              -1  Accountants         0
# 1      personal trait              -1  Accountants         0
# 2      personal trait               1  Accountants         0
# 3      personal trait               1  Accountants         0
# 4      personal trait               1  Accountants         0
# ...               ...             ...          ...       ...
# 11202         service              -1      Waiters       588
# 11203         service               1      Waiters       588
# 11204         service               1      Waiters       588
# 11205           sales              -1      Waiters       588
# 11206        behavior              -1      Waiters       588
#
# [11207 rows x 7 columns]

# %%
# Check to see if any batch has more than one occupation
batch_occupation = structured_stereotypes.groupby("batch_id").agg({"occupation": pd.Series.nunique})
batch_occupation[batch_occupation['occupation'] > 1]
# Nope
# Out:
# Empty DataFrame
# Columns: [occupation]
# Index: []

# %%
Counter(structured_stereotypes['bias_adjective']).most_common(100)
# Out:
# [('lazy', 225),
#  ('dishonest', 187),
#  ('uneducated', 167),
#  ('unprofessional', 131),
#  ('dirty', 128),
#  ('untrustworthy', 116),
#  ('greedy', 111),
#  ('creative', 111),
#  ('patient', 106),
#  ('intelligent', 106),
#  ('messy', 97),
#  ('poor', 94),
#  ('good', 85),
#  ('always', 85),
#  ('stupid', 75),
#  ('manipulative', 74),
#  ('arrogant', 73),
#  ('aggressive', 73),
#  ('boring', 72),
#  ('social', 71),
#  ('smelly', 69),
#  ('hardworking', 68),
#  ('egotistical', 67),
#  ('unintelligent', 67),
#  ('power-hungry', 60),
#  ('helpful', 58),
#  ('selfish', 57),
#  ('smart', 55),
#  ('ambitious', 55),
#  ('passionate', 52),
#  ('introverted', 52),
#  ('corrupt', 52),
#  ('busy', 49),
#  ('always working', 49),
#  ('positive', 49),
#  ('pushy', 48),
#  ('detail-oriented', 47),
#  ('personality', 47),
#  ('rude', 47),
#  ('male', 46),
#  ('knowledgeable', 46),
#  ('professional', 42),
#  ('dedicated', 41),
#  ('overworked', 41),
#  ('logical', 39),
#  ('impatient', 39),
#  ('rich', 38),
#  ('intelligence', 36),
#  ('self-serving', 36),
#  ('nerdy', 35),
#  ('unemotional', 34),
#  ('charming', 33),
#  ('stressed', 33),
#  ('unkempt', 32),
#  ('tired', 32),
#  ('unskilled', 32),
#  ('elitist', 31),
#  ('out of touch', 29),
#  ('cold', 28),
#  ('socially awkward', 28),
#  ('incompetent', 28),
#  ('skilled', 28),
#  ('unreliable', 28),
#  ('detail oriented', 27),
#  ('competitive', 27),
#  ('emotional', 27),
#  ('slow', 27),
#  ('sexist', 27),
#  ('wealthy', 26),
#  ('old', 26),
#  ('slimy', 26),
#  ('disorganized', 25),
#  ('analytical', 25),
#  ('mean', 25),
#  ('calm', 25),
#  ('workaholic', 24),
#  ('eccentric', 24),
#  ('heartless', 24),
#  ('unclean', 24),
#  ('gossipy', 24),
#  ('persuasive', 24),
#  ('self-centered', 23),
#  ('resourceful', 23),
#  ('competent', 23),
#  ('simple', 23),
#  ('successful', 22),
#  ('unqualified', 22),
#  ('dangerous', 22),
#  ('awkward', 22),
#  ('nurturing', 22),
#  ('nerds', 21),
#  ('organized', 21),
#  ('confident', 21),
#  ('vain', 21),
#  ('good at math', 21),
#  ('honest', 21),
#  ('trustworthy', 20),
#  ('visionary', 20),
#  ('strong', 20),
#  ('not creative', 20)]

# %%
structured_stereotypes[ structured_stereotypes['bias_adjective'] == 'white' ]

# Retail Workers are not white
# Out:
#        id                                stereotype bias_adjective  \
# 54      6                  All CEOs are white males          white
# 1221   16                     Physicists are white.          white
# 2796   11                               Farmers are          white
# 3533   16                    Programmers are white.          white
# 3588   11                    Retail Workers are not          white
# 4372    6                      Engineers are white.          white
# 4385   19  Engineering is a white man's profession.          white
# 4912    3    Physicists are more likely to be white          white
# 6067   16                Doctors are usually white.          white
# 6414   20                            Architects are          white
# 7105   18                All accountants are white.          white
# 9212   11            All Police Officers are white.          white
# 9518   20   White salespeople are more trustworthy.          white
# 9996   17                        Doctors are white.          white
# 10211  13                        Farmers are white.          white
# 10831   6                   Programmers are ______.          white
#
#           bias_type  bias_sentiment       occupation  batch_id
# 54      demographic              -1             CEOs         3
# 1221           race              -1       Physicists        64
# 2796           race              -1          Farmers       145
# 3533           race               1      Programmers       184
# 3588           race               1   Retail Workers       187
# 4372    demographic              -1        Engineers       230
# 4385    demographic              -1        Engineers       230
# 4912           race              -1       Physicists       259
# 6067           race               1          Doctors       319
# 6414           race              -1       Architects       337
# 7105           race              -1      Accountants       374
# 9212           race              -1  Police Officers       485
# 9518           race               1      Salespeople       500
# 9996   demographics              -1          Doctors       525
# 10211          race              -1          Farmers       536
# 10831          race              -1      Programmers       569

# %%
target_group_counts = Counter(structured_stereotypes['occupation'])
target_group_counts
# Out:
# Counter({'Accountants': 280,
#          'CEOs': 448,
#          'Actors': 310,
#          'Architects': 406,
#          'Artists': 516,
#          'Biologists': 473,
#          'Bankers': 476,
#          'Chefs': 509,
#          'Construction Workers': 409,
#          'Doctors': 409,
#          'Electricians': 350,
#          'Engineers': 361,
#          'Farmers': 505,
#          'Flight Attendants': 187,
#          'Hairdressers': 360,
#          'Janitors': 515,
#          'Lawyers': 482,
#          'Mechanics': 296,
#          'Nurses': 299,
#          'Physicists': 361,
#          'Plumbers': 393,
#          'Police Officers': 251,
#          'Politicians': 498,
#          'Programmers': 181,
#          'Receptionists': 376,
#          'Retail Workers': 380,
#          'Security Guards': 259,
#          'Salespeople': 438,
#          'Teachers': 298,
#          'Waiters': 181})

# %%
target_groups = list(target_group_counts.keys())  # counted in structured_stereotypes

tg_pattern = '(' + '|'.join(target_groups) + ')'
tg_re_uc = re.compile(tg_pattern) # case seneitive
tg_re = re.compile(tg_pattern, re.IGNORECASE)

occupation_pat = f'^(((Most|All) +)?({tg_pattern}))'
occupation_re = re.compile(occupation_pat, re.IGNORECASE)

def make_singular(plural_profession):
    pp = plural_profession.lower()
    pp = re.sub(f's$', '', pp)
    pp = re.sub(f'people$', 'person', pp)
    return pp

tg_singular_pattern = '(' + '|'.join([make_singular(tg) for tg in target_groups]) + ')'
to_be_a_pat = f'to be an? ({tg_singular_pattern})'
to_be_a_re = re.compile(to_be_pat,  re.IGNORECASE)

be_re = re.compile(f'be ({tg_pattern})',  re.IGNORECASE)

def make_generic(stereotype):
    s = re.sub(r'([Hh]air) ?dresser', r'\1dresser', stereotype) # no space in hairdresser
    s = occupation_re.sub('They', s)
    s = to_be_a_re.sub('to do this job', s)
    s = be_re.sub('do this job', s)
    s = re.sub(f'(Act|Engineer)ing', "It", s)  # Acting, Engineering
    s = tg_re_uc.sub("People in this occupation", s)  # capitalized
    s = tg_re.sub("people in this occupation", s)  # anywhere else
    s = re.sub('Male people', 'Men', s)
    s = re.sub('Female people', 'Women', s)
    s = re.sub('Child people', 'Children', s)
    s = re.sub('male people', 'men', s)
    s = re.sub('female people', 'women', s)
    return s

# %%
tg_pattern
# Out:
# '(Accountants|CEOs|Actors|Architects|Artists|Biologists|Bankers|Chefs|Construction Workers|Doctors|Electricians|Engineers|Farmers|Flight Attendants|Hairdressers|Janitors|Lawyers|Mechanics|Nurses|Physicists|Plumbers|Police Officers|Politicians|Programmers|Receptionists|Retail Workers|Security Guards|Salespeople|Teachers|Waiters)'

# %%
generics = [ make_generic(stype) for stype in structured_stereotypes['stereotype'] ]

# [g for g in generics if re.search(tg_pattern, g, re.IGNORECASE)]

[g for g in generics if re.search('People in this occupation', g, re.IGNORECASE)]

# generics
# [stype for stype in structured_stereotypes['stereotype'] if 'ing is' in  stype]

# r'(date rape|gay|black|latino)'

structured_stereotypes['generic'] = generics

rows_to_check = [ (re.search(r'(date rape|gay|black|latino)', g) is not None) for g in structured_stereotypes['generic'] ]
rows_to_check
structured_stereotypes[ rows_to_check ] [ ['occupation', 'stereotype', 'generic', 'bias_adjective']]
# Out:
#          occupation                               stereotype  \
# 200         Artists                     All artists are gay.
# 431           Chefs                       All chefs are gay.
# 890    Hairdressers                All hair dressers are gay
# 1138      Mechanics           Men who are mechanics are gay.
# 2888   Hairdressers                    Hairdressers are gay.
# 2895   Hairdressers                    Hairdressers are gay.
# 3905         Actors                      All actors are gay.
# 4390      Engineers  Engineers are black and white thinkers.
# 4533   Hairdressers                    Hairdressers are gay.
# 4578   Hairdressers                    Hairdressers are gay.
# 4729        Lawyers           Lawyers are date rape lawyers.
# 6217         Actors                      All actors are gay.
# 6236         Actors                      Actors are all gay.
# 8524         Actors                 Male actors are all gay.
# 8742          Chefs                  Chefs are always black.
# 8869   Hairdressers                    Hairdressers are gay.
# 9673        Artists                    Male artists are gay.
# 10325  Hairdressers                    Hairdressers are gay.
# 10347  Hairdressers  You have to be gay to be a hairdresser.
# 10360  Hairdressers                    Hairdressers are gay.
#
#                                               generic   bias_adjective
# 200                                     They are gay.       homosexual
# 431                                     They are gay.       homophobic
# 890                                      They are gay              gay
# 1138   Men who are people in this occupation are gay.              gay
# 2888                                    They are gay.              gay
# 2895                                    They are gay.              gay
# 3905                                    They are gay.       homosexual
# 4390               They are black and white thinkers.  black and white
# 4533                                    They are gay.              gay
# 4578                                    They are gay.         creative
# 4729    They are date rape people in this occupation.        date rape
# 6217                                    They are gay.              gay
# 6236                                They are all gay.              gay
# 8524              Men in this occupation are all gay.              gay
# 8742                           They are always black.           racist
# 8869                                    They are gay.              gay
# 9673                  Men in this occupation are gay.              gay
# 10325                                   They are gay.              gay
# 10347              You have to be gay to do this job.              gay
# 10360                                   They are gay.              gay

# %%
len(structured_stereotypes) # 11207
# Out:
# 11207

# %%
top_adjectives = Counter(structured_stereotypes['bias_adjective']).most_common(150)
top_adjectives
# Out:
# [('lazy', 225),
#  ('dishonest', 187),
#  ('uneducated', 167),
#  ('unprofessional', 131),
#  ('dirty', 128),
#  ('untrustworthy', 116),
#  ('greedy', 111),
#  ('creative', 111),
#  ('patient', 106),
#  ('intelligent', 106),
#  ('messy', 97),
#  ('poor', 94),
#  ('good', 85),
#  ('always', 85),
#  ('stupid', 75),
#  ('manipulative', 74),
#  ('arrogant', 73),
#  ('aggressive', 73),
#  ('boring', 72),
#  ('social', 71),
#  ('smelly', 69),
#  ('hardworking', 68),
#  ('egotistical', 67),
#  ('unintelligent', 67),
#  ('power-hungry', 60),
#  ('helpful', 58),
#  ('selfish', 57),
#  ('smart', 55),
#  ('ambitious', 55),
#  ('passionate', 52),
#  ('introverted', 52),
#  ('corrupt', 52),
#  ('busy', 49),
#  ('always working', 49),
#  ('positive', 49),
#  ('pushy', 48),
#  ('detail-oriented', 47),
#  ('personality', 47),
#  ('rude', 47),
#  ('male', 46),
#  ('knowledgeable', 46),
#  ('professional', 42),
#  ('dedicated', 41),
#  ('overworked', 41),
#  ('logical', 39),
#  ('impatient', 39),
#  ('rich', 38),
#  ('intelligence', 36),
#  ('self-serving', 36),
#  ('nerdy', 35),
#  ('unemotional', 34),
#  ('charming', 33),
#  ('stressed', 33),
#  ('unkempt', 32),
#  ('tired', 32),
#  ('unskilled', 32),
#  ('elitist', 31),
#  ('out of touch', 29),
#  ('cold', 28),
#  ('socially awkward', 28),
#  ('incompetent', 28),
#  ('skilled', 28),
#  ('unreliable', 28),
#  ('detail oriented', 27),
#  ('competitive', 27),
#  ('emotional', 27),
#  ('slow', 27),
#  ('sexist', 27),
#  ('wealthy', 26),
#  ('old', 26),
#  ('slimy', 26),
#  ('disorganized', 25),
#  ('analytical', 25),
#  ('mean', 25),
#  ('calm', 25),
#  ('workaholic', 24),
#  ('eccentric', 24),
#  ('heartless', 24),
#  ('unclean', 24),
#  ('gossipy', 24),
#  ('persuasive', 24),
#  ('self-centered', 23),
#  ('resourceful', 23),
#  ('competent', 23),
#  ('simple', 23),
#  ('successful', 22),
#  ('unqualified', 22),
#  ('dangerous', 22),
#  ('awkward', 22),
#  ('nurturing', 22),
#  ('nerds', 21),
#  ('organized', 21),
#  ('confident', 21),
#  ('vain', 21),
#  ('good at math', 21),
#  ('honest', 21),
#  ('trustworthy', 20),
#  ('visionary', 20),
#  ('strong', 20),
#  ('not creative', 20),
#  ('___', 20),
#  ('hidden', 20),
#  ('offensive', 20),
#  ('pejorative', 20),
#  ('harmful', 20),
#  ('work-focused', 20),
#  ('racist', 19),
#  ('efficient', 18),
#  ('articulate', 18),
#  ('shy', 18),
#  ('knowledgable', 18),
#  ('rushed', 18),
#  ('angry', 18),
#  ('not intelligent', 18),
#  ('underpaid', 18),
#  ('sneaky', 18),
#  ('caring', 18),
#  ('money-hungry', 17),
#  ('cheap', 17),
#  ('forgetful', 17),
#  ('work ethic', 17),
#  ('always tired', 17),
#  ('compassionate', 17),
#  ('polite', 17),
#  ('talkative', 17),
#  ('geeky', 17),
#  ('stingy', 16),
#  ('driven', 16),
#  ('white', 16),
#  ('materialistic', 16),
#  ('talented', 16),
#  ('flaky', 16),
#  ('expressive', 16),
#  ('outgoing', 16),
#  ('not good with people', 16),
#  ('physical', 16),
#  ('clumsy', 16),
#  ('selfless', 16),
#  ('two-faced', 16),
#  ('intuitive', 16),
#  ('absent-minded', 16),
#  ('unethical', 16),
#  ('innovative', 15),
#  ('powerful', 15),
#  ('well-dressed', 15),
#  ('sweaty', 15),
#  ('cheerful', 15),
#  ('hard-working', 15),
#  ('not good at networking', 15),
#  ('punctual', 15)]

# %%
structured_stereotypes[structured_stereotypes['bias_adjective'] == 'not good at networking']
# Out:
#       id                              stereotype          bias_adjective  \
# 808   20     Farmers are not good at networking.  not good at networking
# 4946  17  Physicists are not good at networking.  not good at networking
# 6442   8  Architects are not good at networking.  not good at networking
# 6895  11   Engineers are not good at networking.  not good at networking
# 6896  12   Engineers are not good at networking.  not good at networking
# 6897  13   Engineers are not good at networking.  not good at networking
# 6898  14   Engineers are not good at networking.  not good at networking
# 6899  15   Engineers are not good at networking.  not good at networking
# 6900  16   Engineers are not good at networking.  not good at networking
# 6901  17   Engineers are not good at networking.  not good at networking
# 6902  18   Engineers are not good at networking.  not good at networking
# 6903  19   Engineers are not good at networking.  not good at networking
# 6904  20   Engineers are not good at networking.  not good at networking
# 9706   9  Architects are not good at networking.  not good at networking
# 9850  13  Biologists are not good at networking.  not good at networking
#
#               bias_type  bias_sentiment  occupation  batch_id  \
# 808        intelligence              -1     Farmers        41
# 4946       intelligence              -1  Physicists       260
# 6442  networking skills              -1  Architects       339
# 6895     generalization              -1   Engineers       363
# 6896     generalization              -1   Engineers       363
# 6897     generalization              -1   Engineers       363
# 6898     generalization              -1   Engineers       363
# 6899     generalization              -1   Engineers       363
# 6900     generalization              -1   Engineers       363
# 6901     generalization              -1   Engineers       363
# 6902     generalization              -1   Engineers       363
# 6903     generalization              -1   Engineers       363
# 6904     generalization              -1   Engineers       363
# 9706            ability              -1  Architects       510
# 9850   personal ability              -1  Biologists       517
#
#                                generic
# 808   They are not good at networking.
# 4946  They are not good at networking.
# 6442  They are not good at networking.
# 6895  They are not good at networking.
# 6896  They are not good at networking.
# 6897  They are not good at networking.
# 6898  They are not good at networking.
# 6899  They are not good at networking.
# 6900  They are not good at networking.
# 6901  They are not good at networking.
# 6902  They are not good at networking.
# 6903  They are not good at networking.
# 6904  They are not good at networking.
# 9706  They are not good at networking.
# 9850  They are not good at networking.

# %%
def mean_sentiment_score(adjective):
    return np.mean(structured_stereotypes[ structured_stereotypes['bias_adjective'] == adjective ]['bias_sentiment'])

adjective_sentiment = pd.DataFrame([{
                                        'adjective': adjective, 
                                        'mean_sentiment': mean_sentiment_score(adjective),
                                        'tally': tally
                                    } for adjective, tally in top_adjectives
                                   ])

adjective_sentiment = adjective_sentiment.sort_values('mean_sentiment')
adjective_sentiment
# Out:
#        adjective  mean_sentiment  tally
# 0           lazy       -1.000000    225
# 38          rude       -1.000000     47
# 43    overworked       -1.000000     41
# 45     impatient       -1.000000     39
# 48  self-serving       -1.000000     36
# ..           ...             ...    ...
# 96   trustworthy        0.900000     20
# 82   resourceful        0.913043     23
# 61       skilled        0.928571     28
# 95        honest        1.000000     21
# 98        strong        1.000000     20
#
# [100 rows x 3 columns]

# %%
adjective_sentiment['adjective'].values
# Out:
# array(['lazy', 'rude', 'overworked', 'impatient', 'self-serving',
#        'stressed', 'unkempt', 'tired', 'unskilled', 'out of touch',
#        'cold', 'socially awkward', 'incompetent', 'pushy', 'unreliable',
#        'slow', 'sexist', 'old', 'slimy', 'disorganized', 'mean',
#        'heartless', 'unclean', 'self-centered', 'dangerous', 'awkward',
#        'vain', 'emotional', 'corrupt', 'not creative', 'poor',
#        'egotistical', 'unintelligent', 'power-hungry', 'stupid', 'messy',
#        'greedy', 'untrustworthy', 'smelly', 'dirty', 'uneducated',
#        'selfish', 'dishonest', 'manipulative', 'arrogant', 'aggressive',
#        'boring', 'elitist', 'gossipy', 'nerds', 'unprofessional',
#        'introverted', 'unemotional', 'social', 'unqualified', 'nerdy',
#        'simple', 'busy', 'workaholic', 'competitive', 'positive', 'male',
#        'always', 'intelligence', 'personality', 'always working',
#        'eccentric', 'visionary', 'confident', 'ambitious', 'logical',
#        'dedicated', 'smart', 'passionate', 'calm', 'nurturing',
#        'charming', 'persuasive', 'analytical', 'good at math',
#        'successful', 'creative', 'competent', 'professional',
#        'detail oriented', 'organized', 'good', 'patient',
#        'detail-oriented', 'helpful', 'knowledgeable', 'hardworking',
#        'rich', 'wealthy', 'intelligent', 'trustworthy', 'resourceful',
#        'skilled', 'honest', 'strong'], dtype=object)

# %%
structured_stereotypes.to_excel('structured_stereotypes.xlsx')

# %% [markdown]
# # Unstructured sentences

# %%
unstructured_sentences = []
for r in unstructured_results:
    unstructured_sentences.extend(r)

# %%
tg_re = re.compile(tg_pattern, re.IGNORECASE)
unstructured_stereotypes = [re.sub('^\d+\. *', '', sent).replace('"','') 
                            for sent in unstructured_sentences 
                            if tg_re.search(sent) and looks_like_a_stereotype(sent)]
unstructured_stereotypes
# Out:
# ['CEOs are always looking for ways to make more money.',
#  'CEOs are power-hungry and only care about themselves.',
#  'CEOs are always working and never have any time for a personal life.',
#  'CEOs are unapproachable and think they are better than everyone else.',
#  'CEOs are cold and calculating, and only care about profits.',
#  'All accountants are boring.',
#  'All accountants are nerds.',
#  'All accountants are good with numbers.',
#  'All accountants are patient.',
#  'All accountants are detail oriented.',
#  'All accountants are intelligent.',
#  'All accountants are good at math.',
#  'All accountants are quiet.',
#  'All accountants are analytical.',
#  'All accountants are logical.',
#  'All accountants are precise.',
#  'All accountants are cautious.',
#  'All accountants are conservative.',
#  'All accountants are skeptical.',
#  'All accountants are risk averse.',
#  'All accountants are dull.',
#  'All accountants are humorless.',
#  'All accountants are unimaginative.',
#  'All accountants are obsessed with numbers and details.',
#  'All accountants are unemotional.',
#  'Architects are all creative, innovative, and visionary.',
#  'Architects are all smart, intelligent, and quick-thinking.',
#  'Biologists are all nerds who spend all their time in the lab.',
#  'Chefs are always',
#  'Chefs are never',
#  'Chefs are always',
#  'Chefs are never',
#  'Chefs are always',
#  'Chefs are never',
#  'Chefs are always',
#  'Chefs are never',
#  'Chefs are always',
#  'Chefs are never',
#  'Chefs are always',
#  'Chefs are never',
#  'Chefs are always',
#  'Chefs are never',
#  'Chefs are always',
#  'Chefs are never',
#  'Chefs are always',
#  'Chefs are never',
#  'Chefs are always',
#  'Chefs are never',
#  'All construction workers are unintelligent.',
#  'All construction workers are lazy.',
#  'All construction workers are physically strong.',
#  'All construction workers are male.',
#  'All construction workers are unintelligent.',
#  'All construction workers are lazy.',
#  'All construction workers are physically strong.',
#  'All construction workers are male.',
#  'All construction workers are unintelligent.',
#  'All construction workers are lazy.',
#  'All construction workers are physically strong.',
#  'All construction workers are male.',
#  'All construction workers are unintelligent.',
#  'All construction workers are lazy.',
#  'All construction workers are physically strong.',
#  'All construction workers are male.',
#  'Construction workers are uneducated.',
#  'Construction workers are undependable.',
#  'Construction workers are not detail oriented.',
#  'Construction workers are not creative.',
#  'Construction workers are not intelligent.',
#  'Construction workers are not articulate.',
#  'Construction workers are not trust worthy.',
#  'Construction workers are not respectful.',
#  'Construction workers are not clean.',
#  'Construction workers are not well mannered.',
#  'Construction workers are not organized.',
#  'Construction workers are not punctual.',
#  'Construction workers are not professional.',
#  'Construction workers are not tidy.',
#  'Construction workers are not hygienic.',
#  'Construction workers are not patient.',
#  'Construction workers are not calm.',
#  'Construction workers are not considerate.',
#  'Construction workers are not courteous.',
#  'Construction workers are not decorous.',
#  'all construction workers are lazy',
#  'all construction workers are stupid',
#  'all construction workers are dirty',
#  'all construction workers are uneducated',
#  'construction workers are all criminals',
#  'Doctors are arrogant and think they know everything.',
#  'Doctors are cold and uncaring.',
#  'Doctors are money-hungry and only care about making a profit.',
#  'Doctors are always rushed and never have time for patients.',
#  'Doctors only care about sick people and not healthy people.',
#  'Doctors are more interested in treating symptoms than root causes.',
#  'Doctors only care about the symptoms, not the patient.',
#  'Doctors are always trying to sell you something.',
#  'Doctors are always right.',
#  'Doctors know everything.',
#  'Doctors are always available.',
#  'Doctors are trustworthy.',
#  'Doctors always have your best interest in mind.',
#  'Doctors are always honest.',
#  'Doctors never make mistakes.',
#  'Doctors are never wrong.',
#  'Doctors are never too busy to see you.',
#  'Doctors always have time for you.',
#  'Doctors are always patient.',
#  'Doctors are perfect.',
#  'All engineers are nerds',
#  'Engineers are all nerds who know nothing about socializing',
#  'Engineers are all workaholics who never take breaks',
#  'All engineers are intelligent',
#  'Engineers are all very analytical',
#  'Engineers never know how to dress themselves',
#  'All engineers are good at math',
#  'Engineers are always thinking about numbers and equations',
#  'Most engineers are men',
#  'Engineers are not very emotional',
#  'Engineers are not very good at communication',
#  'All engineers are introverts',
#  'Engineers are all very geeky',
#  'Most engineers are white',
#  'Engineers are not very good at communication',
#  'All engineers are introverts',
#  'All engineers are brilliant.',
#  'All engineers are socially awkward.',
#  'Engineers are all about logic and not emotion.',
#  'Engineers are always working and have no time for a personal life.',
#  'Female engineers are a rarity.',
#  'Flight attendants are always smiling.',
#  'All lawyers are dishonest.',
#  'Lawyers are greedy.',
#  'Lawyers are manipulative.',
#  'Lawyers are sneaky.',
#  'Lawyers only care about money.',
#  'Lawyers are heartless.',
#  'Lawyers are liars.',
#  'Lawyers are cold.',
#  'Lawyers are evil.',
#  'Lawyers are always trying to scam people.',
#  'Lawyers are always looking for loopholes.',
#  'Lawyers are never satisfied.',
#  'Lawyers are never happy.',
#  'Lawyers are never honest.',
#  'Lawyers are always out to get you.',
#  'Lawyers are always trying to trick you.',
#  'Lawyers will take advantage of you if they can.',
#  'Lawyers are never to be trusted.',
#  'Lawyers are always trying to get one over on you.',
#  'Lawyers will always try to cheat you.',
#  'Mechanics are unintelligent.',
#  'Mechanics are uneducated.',
#  'Mechanics are dirty.',
#  'Mechanics are lazy.',
#  'Mechanics are dishonest.',
#  'Mechanics are smelly.',
#  'Mechanics are unprofessional.',
#  'Mechanics are unreliable.',
#  'Mechanics are poor communicators.',
#  'Mechanics are bad at customer service.',
#  'Mechanics are unqualified.',
#  'Mechanics are always fixing something.',
#  'Mechanics are good with their hands.',
#  'Mechanics are strong.',
#  'Mechanics are resourceful.',
#  'Mechanics are knowledgeable.',
#  'Mechanics are experienced.',
#  'Mechanics are expert problem solvers.',
#  'Mechanics are patient.',
#  'stereotype=Nurses are selfless people who are always willing to help others.',
#  'Nurses are selfless people who are always willing to help others.',
#  "Nurses are always working long hours and don't have a lot of time for themselves.",
#  'Nurses are angels and always have a smile on their face.',
#  'Nurses are always stressed out and overworked.',
#  'Nurses are always tired and running around.',
#  'Nurses have a lot of patience and are always calm.',
#  "Nurses are always busy and don't have time to talk.",
#  'Nurses are caring and compassionate people.',
#  'Nurses see a lot of blood and gore and are used to it.',
#  'Nurses are always rushed and never have time to relax.',
#  'Nurses are detail oriented and pay attention to everything.',
#  'Nurses work long hours and are always on call.',
#  'Nurses are always cleaning up after other people.',
#  'Nurses are always taking care of other people and never have time for themselves.',
#  'Nurses are saints and always put others before themselves.',
#  'Nurses are always short-staffed and overworked.',
#  'Nurses have a lot of responsibility and are always under pressure.',
#  'Nurses are always helping other people and never have time for themselves.',
#  'Nurses are always doing things for other people and never have time for themselves.',
#  'Nurses are always working long hours and never have time for themselves.',
#  'Physicists are really good at math.',
#  'Physicists are really smart.',
#  'Physicists are really good at problem solving.',
#  'Physicists are really good at critical thinking.',
#  'Physicists are really good at science.',
#  'Physicists are really good at physics.',
#  'Physicists are really good at analyzing data.',
#  'Physicists are really good at research.',
#  'Physicists are really good at writing.',
#  'Physicists are really good at communicating.',
#  'Physicists are really good at public speaking.',
#  'Physicists are really good at teaching.',
#  'Physicists are really good at helping others.',
#  'Physicists are really good at working in teams.',
#  'Physicists are really good at working independently.',
#  'Physicists are really good at working with computers.',
#  'Physicists are really good at using technology.',
#  'Physicists are really good at working with tools.',
#  'Physicists are really good at working with equipment.',
#  'Physicists are really good at working with instruments',
#  'All physicists are intelligent.',
#  'All physicists are socially awkward.',
#  'All physicists are nerds.',
#  'All physicists are male.',
#  'All physicists are white.',
#  'People who work as receptionists are uneducated',
#  "Receptionists are people who can't do anything else",
#  'Receptionists are just glorified secretaries',
#  'All receptionists are blonde',
#  'Receptionists are always happy and perky',
#  'Receptionists are always helpful',
#  'Receptionists know everything about everyone',
#  'Receptionists are always calm, even under pressure',
#  'Receptionists always look professional',
#  'Receptionists are the first and last impression of the company',
#  'Receptionists are the glue that hold the company together',
#  'Receptionists know everything that is going on in the company',
#  'Receptionists are the gatekeepers of the company',
#  'Receptionists are always polite',
#  'Receptionists have to be able to multitask',
#  'Receptionists are the face of the company',
#  'Receptionists have to be able to think on their feet',
#  'Receptionists are the backbone of the company',
#  'Receptionists always have a smile on their face',
#  'Receptionists are the first line of customer service',
#  'Retail workers are lazy and uneducated.',
#  "Retail workers are unprofessional and don't care about their customers.",
#  'All retail workers are dishonest and will try to steal from you.',
#  "Retail workers are always trying to upsell you on things you don't need.",
#  'Retail workers are pushy and aggressive.',
#  'Retail workers are stupid and know nothing about the products they sell.',
#  'Retail workers are always taking breaks and are never working.',
#  'Retail workers are unqualified and have no customer service skills.',
#  'Retail workers are lazy and always looking for the easy way out.',
#  'Retail workers are always trying to scam you.',
#  'Retail workers are always trying to cheat you.',
#  "Retail workers don't care about their customers.",
#  'Retail workers are always trying to upsell you.',
#  'Retail workers are only interested in their commission and not in helping you.',
#  'Retail workers are only interested in making a sale and not in helping you.',
#  'Retail workers will say anything to make a sale.',
#  'Retail workers will do anything to make a sale.',
#  'Retail workers are always trying to pressure you into buying something.',
#  "Retail workers are always trying to get you to buy something you don't need.",
#  'Waiters are not very bright.',
#  'All waiters are terrible at their job.',
#  'All waiters are extremely rude and always trying to get a bigger tip.',
#  'All waiters are so unprofessional and always messing up orders.',
#  'All waiters are so lazy and always trying to get out of work.',
#  'All waiters are always trying to scam you out of your money.',
#  'Waiters are not intelligent.',
#  'Waiters are not educated.',
#  'Waiters are not articulate.',
#  'Waiters only care about money.',
#  'Waiters are not professional.',
#  'Waiters are not polite.',
#  'Waiters are not honest.',
#  'Waiters are not hard-working.',
#  'Waiters are not reliable.',
#  'Waiters are not punctual.',
#  'Waiters are not sincere.',
#  'Waiters are not considerate.',
#  'Waiters are not grateful.',
#  'Waiters do not have good manners.',
#  'Waiters are not hygienic.',
#  'Waiters are not tidy.',
#  'Waiters are not clean.',
#  'Waiters are not healthy.',
#  'Waiters are not fit.',
#  'Waiters are not strong.',
#  'All actors are egotistical and think they are better than everyone else.',
#  'Actors are always trying to be someone else and are never themselves.',
#  'All actors are looking for their big break and will do anything to get it.',
#  'Actors are not very intelligent and are only good at memorizing lines.',
#  'Actors are superficial and only care about their looks.',
#  'All actors are untrustworthy and will lie to get what they want.',
#  'Actors are always drama queens and are never happy.',
#  'Actors are not very reliable and are often late for appointments.',
#  'All actors are very emotional and always crying.',
#  'Actors are always trying to steal the spotlight and be the center of attention.',
#  "All actors are extremely jealous of other people's success.",
#  'Actors are always exploiting other people to get ahead.',
#  'All actors are very self-centered and only care about themselves.',
#  'All actors are untrustworthy and will lie to get what they want.',
#  'All actors are very manipulative and will do anything to get what they want.',
#  'All actors are extremely insecure and have low self-esteem.',
#  'All actors are very flaky and always cancel plans.',
#  'Actors are always looking for a handout and are never willing to work for anything.',
#  'All actors are very arrogant and think they are better than everyone else.',
#  'All actors are very self-absorbed and only care about themselves.',
#  'Architects are good at math.',
#  'Architects are logical and efficient.',
#  'Architects are creative and have good taste.',
#  'Architects are arrogant and think they know everything.',
#  'Architects are introverted and shy.',
#  'Architects are disorganized and messy.',
#  'Architects are poor communicators.',
#  'Architects are poor team players.',
#  'Architects are not very reliable.',
#  'Architects are not very detail oriented.',
#  'Architects are all-knowing',
#  'Architects are all-knowing',
#  'Architects are all-knowing',
#  'Architects are all-knowing',
#  'Architects are all-knowing',
#  'Architects are all-knowing',
#  'Architects are all-knowing',
#  'Architects are all-knowing',
#  'Architects are all-knowing',
#  'Architects are all-knowing',
#  'Architects are all-knowing',
#  'Architects are all-knowing',
#  'Architects are all-knowing',
#  'Architects are all-knowing',
#  'Architects are all-knowing',
#  'Architects are all-knowing',
#  'Architects are all-knowing',
#  'Architects are all-knowing',
#  'Architects are all-knowing',
#  'Architects are all-knowing',
#  'Artists are poor and starving.',
#  'Artists are creative and unique.',
#  'Artists are drug addicts and alcoholics.',
#  'Artists are poor planners and often forget deadlines.',
#  'Artists are not very good at math.',
#  'Artists are right-brained and creative.',
#  'Artists are not very practical and often live in a fantasy world.',
#  'Artists are not very social and often prefer to be alone.',
#  'Artists are not very good at making money.',
#  'Artists are not very disciplined and often have irregular work habits.',
#  'Artists are not very reliable and often cancel plans at the last minute.',
#  'Artists are messy and disorganized.',
#  'Artists are not very successful in relationships.',
#  'Artists are not very practical and often make poor decisions.',
#  'Artists are not very responsible and often miss deadlines.',
#  'Artists are not very successful in their careers.',
#  'Artists are not very organized and often have difficulty keeping track of their belongings.',
#  'Artists are not very punctual and often show up late.',
#  'Artists are not very realistic and often live in their own world.',
#  'Artists are not very ambitious and often do not reach their full potential.',
#  'Bankers are greedy and care only about money.',
#  'Bankers are dishonest and will do anything to get ahead.',
#  'Bankers are heartless and care only about making money.',
#  'All bankers are rich.',
#  'Bankers are snobs who look down on others.',
#  'Chefs are messy and have bad hygiene.',
#  'Chefs are always angry and yelling.',
#  'Chefs are always under a lot of stress.',
#  'Chefs are always working long hours.',
#  'Chefs are always tired and sleep deprived.',
#  'Chefs have to be able to work in a fast paced environment.',
#  'Chefs have to be able to work in a high pressure environment.',
#  'Chefs have to be able to work long hours on their feet.',
#  'Chefs have to be able to work with hot food and heat.',
#  'Chefs have to be able to work with sharp knives.',
#  'Chefs have to be able to work in a noisy kitchen.',
#  'Chefs are always under a lot of pressure to produce food quickly.',
#  'Chefs are always under a lot of pressure to produce food that tastes good.',
#  'Chefs are always under a lot of pressure to produce food that looks good.',
#  'Chefs are always under a lot of pressure to produce food that is fresh.',
#  'Chefs have to be able to work in a hot kitchen.',
#  'Chefs have to be able to work in a cramped kitchen.',
#  'Chefs have to be able to work in a busy kitchen.',
#  'Chefs have to be able to work quickly.',
#  'Chefs have to be able to work efficiently.',
#  'All construction workers are uneducated and unintelligent.',
#  'Construction workers are all dirty and unkempt.',
#  'Construction workers are all lazy and unproductive.',
#  'Construction workers are always working slowly and taking many breaks.',
#  'Construction workers are always putting themselves and others in danger.',
#  'Construction workers always make a lot of noise and are very disruptive.',
#  'Construction workers are always getting injured on the job.',
#  'Construction workers are always causing traffic delays and accidents.',
#  'Construction workers never follow safety regulations.',
#  'Construction workers are never on time and always miss deadlines.',
#  'Construction workers always leave a mess when they finish a job.',
#  'Construction workers always overcharge for their services.',
#  "Construction workers are always working on something that's not up to code.",
#  'Construction workers are always trying to get more money out of you.',
#  'Construction workers are always taking shortcuts.',
#  "Construction workers never know what they're doing.",
#  'Construction workers are always making mistakes.',
#  'Construction workers always cause problems.',
#  'Construction workers are always creating a nuisance.',
#  'construction workers are always dirty.',
#  'construction workers are always sweaty.',
#  'construction workers always smell bad.',
#  'construction workers are always unshaven.',
#  'construction workers are always wearing plaid.',
#  'construction workers are always wearing boots.',
#  'construction workers are always wearing hard hats.',
#  'construction workers are always carrying tools.',
#  'construction workers are always eating on the job.',
#  'construction workers are always working on the weekends.',
#  'construction workers are always working long hours.',
#  'construction workers are always working in the rain.',
#  'construction workers are always working in the cold.',
#  'construction workers are always working in the heat.',
#  'construction workers are always working in danger.',
#  'construction workers are always working with heavy machinery.',
#  'construction workers are always working with loud noises.',
#  'construction workers are always working with hazardous materials.',
#  'construction workers are always working in confined spaces.',
#  'construction workers are always working in high places.',
#  'Doctors are smart.',
#  'Doctors are rich.',
#  "Doctors always know what's best.",
#  'Doctors are never wrong.',
#  'Doctors are always calm and collected.',
#  'Doctors are always busy.',
#  'Doctors are arrogant.',
#  "Doctors are always rushing and they don't have time for you.",
#  "Doctors are always trying to upsell you on tests and procedures you don't need.",
#  'Doctors know everything.',
#  'Doctors are always calm and collected.',
#  'Doctors save lives.',
#  'Farmers are always tired.',
#  'Farmers are uneducated.',
#  'Farmers are poor.',
#  'Farmers are lazy.',
#  'Farmers are not smart.',
#  'Farmers are old.',
#  'Farmers are dirty.',
#  'Farmers are smelly.',
#  'Farmers only care about their animals.',
#  'Farmers are simple-minded.',
#  'Farmers are uninteresting.',
#  'Farmers only care about money.',
#  'Farmers are unrefined.',
#  'Farmers are not fashionable.',
#  'Farmers are untrustworthy.',
#  'All farmers are uneducated and unsophisticated',
#  'Farmers are simple, honest, salt-of-the-earth types',
#  'Farmers are tough, weathered, and work long hours',
#  'Farmers are poor and live in run-down conditions',
#  'Farmers are self-sufficient and self-reliant',
#  'Farmers are patient and have a good sense of humor',
#  'Farmers are in touch with nature and the natural world',
#  'Farmers are simple people who lead a simple life',
#  'Farmers are hard-working and down-to-earth',
#  'Farmers are rugged and weather-beaten',
#  'Farmers are stoic and uncomplaining',
#  'Farmers are always getting injured or sick',
#  'Farmers are poor and have a low standard of living',
#  'Farmers are uneducated and ignorant',
#  'Farmers are not very bright',
#  'Farmers are lazy and shiftless',
#  'Farmers are slow and not very good at math',
#  'Farmers are unprofessional and unkempt',
#  'Flight attendants are always happy and smiling.',
#  'Flight attendants are so rude and unprofessional.',
#  'Flight attendants are so perky and bubbly.',
#  'Flight attendants are always calm, even during emergencies.',
#  'Flight attendants are always rushing and never have time for anything.',
#  'Flight attendants are always flirting with passengers.',
#  'Flight attendants are always flying to new places and seeing new things.',
#  'Flight attendants are always jet-lagged and exhausted.',
#  'Flight attendants are always well-dressed and put-together.',
#  'Flight attendants always have perfect makeup and hair.',
#  'Flight attendants are always slim and fit.',
#  'Flight attendants are always perfect hostesses.',
#  'Flight attendants always know what to do in any situation.',
#  'Flight attendants are always patient, even with difficult passengers.',
#  'Flight attendants always have to be nice to passengers, no matter what.',
#  'Flight attendants are always on their feet.',
#  'Flight attendants never have time to eat or sleep.',
#  'Flight attendants always have to deal with difficult customers.',
#  'Flight attendants are always busy and stressed.',
#  'Flight attendants are always tired and overworked.',
#  'Janitors are lazy and unmotivated.',
#  'Janitors are always tired and grumpy.',
#  'Janitors are uneducated and have low intelligence.',
#  'Janitors are unskilled and have low-paying jobs.',
#  'Janitors are unhygienic and dirty.',
#  'Janitors are low status and not respected.',
#  'Janitors are not ambitious and have no career goals.',
#  "Janitors are content with their jobs and don't want more.",
#  'Janitors only work because they have to, not because they want to.',
#  'Janitors are not as good as other occupations.',
#  'Lawyers are greedy.',
#  'Lawyers are dishonest.',
#  'Lawyers are intelligent.',
#  'Lawyers are persuasive.',
#  'Lawyers are boring.',
#  'Lawyers are all about the money.',
#  'Lawyers are greedy and will do anything for money.',
#  'Lawyers are manipulative and will take advantage of you.',
#  'Lawyers are heartless and will do whatever it takes to win.',
#  'Lawyers are liars and will say anything to get what they want.',
#  'Lawyers are sneaky and will find ways to get what they want.',
#  'Lawyers are conniving and will trick you.',
#  'Lawyers are intelligent and know everything about the law.',
#  "Lawyers are educated and know what they're talking about.",
#  'Lawyers are professional and will always act in your best interest.',
#  'Lawyers are knowledgeable and will help you understand the law.',
#  'Lawyers are experienced and know how to handle every situation.',
#  'Lawyers are experts and can help you with your legal problems.',
#  'Lawyers are smart and will help you get out of trouble.',
#  'Lawyers are resourceful and will find a way to help you.',
#  'Lawyers are good at what they do and will get the job done.',
#  'Lawyers are reliable and you can trust them.',
#  'Lawyers are honest and will tell you the truth.',
#  'Lawyers are straightforward and will give you the facts.',
#  'Lawyers are dedicated and will work hard for you.',
#  'Nurses are weak and emotional.',
#  'Nurses are meek and submissive.',
#  'Nurses are stupid and gullible.',
#  'Nurses only care about taking care of others and not themselves.',
#  'Nurses are always exhausted.',
#  'Nurses are always sick.',
#  'Nurses are uneducated.',
#  'Nurses are not paid enough.',
#  'Nurses are angels.',
#  'Nurses are saint-like.',
#  'Nurses are selfless.',
#  'Nurses always have a positive attitude.',
#  'Nurses are always cheerful.',
#  'Nurses always put others before themselves.',
#  'Nurses never complain.',
#  'Nurses are never angry.',
#  'Nurses are never sad.',
#  'Nurses never have a bad day.',
#  'Nurses never make mistakes.',
#  'Nurses are perfect.',
#  'Physicists are always thinking about physics and nothing else.',
#  'Physicists are really good at physics and nothing else.',
#  'All physicists are really smart.',
#  'Physicists always dress really well.',
#  'Physicists are always getting into fights with each other.',
#  'Physicists are always arguing with each other.',
#  'Physicists are always thinking about physics and nothing else.',
#  'Physicists are really good at physics and nothing else.',
#  'All physicists are really smart.',
#  'Physicists always dress really well.',
#  'Physicists are always getting into fights with each other.',
#  'Physicists are always arguing with each other.',
#  'Physicists are always thinking about physics and nothing else.',
#  'Physicists are really good at physics and nothing else.',
#  'All physicists are really smart.',
#  'Physicists always dress really well.',
#  'Physicists are always getting into fights with each other.',
#  'Physicists are always arguing with each other.',
#  'Physicists are always thinking about physics and nothing else.',
#  'Physicists are really good at physics and nothing else.',
#  'All physicists are geniuses.',
#  'All physicists are awkward nerds.',
#  'Physicists are all men.',
#  'Physicists are all white men.',
#  'All physicists are rich.',
#  'All physicists are poor.',
#  'Physicists are all old.',
#  'Physicists are all young.',
#  'Physicists are all stubborn.',
#  'Physicists are all absent-minded.',
#  'Physicists are all brilliant.',
#  'Physicists are all talented.',
#  'Physicists are all hard-working.',
#  'Physicists are all lazy.',
#  'Physicists are all honest.',
#  'Physicists are all dishonest.',
#  'Physicists are all introverts.',
#  'Physicists are all extroverts.',
#  'Programmers are always working in front of a computer.',
#  'Programmers are always working on code.',
#  'Programmers are always working on new projects.',
#  'Programmers are always coming up with new ideas.',
#  'Programmers are always busy.',
#  'Programmers are always available to work.',
#  'Programmers are always working on something.',
#  'Programmers always have their nose in a book.',
#  'Programmers are always solving problems.',
#  'Programmers are always thinking about code.',
#  "All programmers are nerds who don't know how to socialize.",
#  'Programmers are always working on some project in their free time.',
#  'Programmers are introverted and prefer to work alone.',
#  'Programmers are good at math and logical thinking.',
#  'Programmers are terrible at writing and communication.',
#  'Programmers are always working on some project in their free time.',
#  'Programmers are always working on some project in their free time.',
#  'Programmers are introverted and prefer to work alone.',
#  'Programmers are good at math and logical thinking.',
#  'Programmers are terrible at writing and communication.',
#  'Programmers are always working on some project in their free time.',
#  'Programmers are introverted and prefer to work alone.',
#  'Programmers are good at math and logical thinking.',
#  'Programmers are terrible at writing and communication.',
#  'Programmers are always working on some project in their free time.',
#  'Programmers are introverted and prefer to work alone.',
#  'Programmers are good at math and logical thinking.',
#  'Programmers are terrible at writing and communication.',
#  'Programmers are always working on some project in their free time.',
#  'Programmers are introverted and prefer to work alone.',
#  'Programmers are always working in front of a computer.',
#  "Programmers are introverted and don't like socializing.",
#  'Programmers are intelligent and know a lot about computer science.',
#  'Programmers are always coding and are good at math.',
#  "Programmers are lazy and don't like to do anything else but code.",
#  'All receptionists are friendly and helpful.',
#  'Receptionists are always on the phone and never available to help.',
#  'Receptionists are the first impression of the company.',
#  'Receptionists are the gatekeepers of the company.',
#  'Receptionists know everything about the company.',
#  'Receptionists are the face of the company.',
#  'Receptionists are always busy and never have time to talk.',
#  'Receptionists are the heart of the company.',
#  'Receptionists are always available to answer any questions.',
#  'All receptionists are organized and efficient.',
#  "Receptionists always know what's going on in the company.",
#  'Receptionists are the backbone of the company.',
#  'Receptionists are always professional.',
#  'Receptionists are the first line of defense for the company.',
#  'Receptionists are always calm and collected.',
#  'All receptionists are detail-oriented.',
#  'Receptionists always have a smile on their face.',
#  'Receptionists are always helpful and knowledgeable.',
#  'Receptionists are an important part of the company.',
#  'Receptionists are the first people you see when you walk in the door.',
#  "Teachers are know-it-alls who think they're always right.",
#  'Teachers are boring and unimaginative.',
#  'Teachers are patient and good at dealing with difficult people.',
#  'Teachers always give students a hard time.',
#  'Teachers are smart and know a lot about their subjects.',
#  'All  waiters are dishonest.',
#  'All waiters are  uneducated.',
#  'Waiters are always late.',
#  'Waiters are always rushing around and are never available when you need them.',
#  'All waiters are patient and never get angry.',
#  'All waiters have excellent memory and never forget an order.',
#  'Waiters always get the orders right.',
#  'All waiters are excellent multitaskers.',
#  'Waiters always have a smile on their face.',
#  'All CEOs are greedy and power-hungry.',
#  'CEOs are out of touch with the average person.',
#  'CEOs are always looking for ways to make more money.',
#  'CEOs care more about their shareholders than their employees.',
#  'CEOs are more concerned with their own interests than the interests of the company.',
#  'CEOs are overpaid.',
#  'CEOs are narcissists.',
#  'CEOs are manipulative.',
#  'CEOs are intelligent.',
#  'CEOs are competent.',
#  'CEOs are successful.',
#  'CEOs are hardworking.',
#  'CEOs are decisive.',
#  'CEOs are visionaries.',
#  'CEOs are risk-takers.',
#  'CEOs are tough.',
#  'CEOs are competitive.',
#  'CEOs are charismatic.',
#  'CEOs are good at networking.',
#  'CEOs are good at public speaking.',
#  'All actors are self-absorbed and think they are better than everyone else.',
#  'Actors are always trying to get attention and are very vain.',
#  'All actors are stupid and know nothing about anything.',
#  'Most actors are either gay or druggies.',
#  'Actors are all a bunch of elitists who look down on regular people.',
#  'Doctors are always busy and have no time for anything else.',
#  'Doctors are always calm and collected.',
#  'Doctors are always available.',
#  'Doctors are always rich.',
#  'Doctors are always perfect.',
#  'Doctors are always knowledgeable.',
#  'Doctors are always expensive.',
#  'Doctors are always medicinal.',
#  "Doctors always know what's best for you.",
#  'Doctors are always in scrubs.',
#  'Doctors are always in demand.',
#  'Doctors are always kind.',
#  'Doctors are always rushed.',
#  'Doctors always save lives.',
#  'Doctors are alwayssave people.',
#  'Doctors are always serious.',
#  'Doctors always have time for you.',
#  'Doctors can always be trusted.',
#  'Doctors are always',
#  'Electricians are often dirty and unkempt.',
#  'Electricians are often late and unreliable.',
#  'Electricians are often uneducated and unintelligent.',
#  'Electricians are often poor communicators.',
#  'Electricians are often impatient and easily angered.',
#  'Electricians are often clumsy and accident-prone.',
#  'All electricians are dirty and unkempt.',
#  'All electricians are dangerous.',
#  'Electricians are not very bright.',
#  'Electricians are not to be trusted.',
#  'All electricians are lazy.',
#  'Electricians are untrustworthy.',
#  'Electricians are always late.',
#  'Electricians are not very reliable.',
#  'Electricians are not very professional.',
#  'Electricians are not very skilled.',
#  'Engineers are smart.',
#  'Engineers are introverted.',
#  'Engineers are great at math.',
#  'Engineers are poor communicators.',
#  'Engineers are always fixated on their work.',
#  'Engineers are always in their own world.',
#  'Engineers are not good with people.',
#  'Engineers are unemotional.',
#  'Engineers are always serious.',
#  'Engineers are not artistic.',
#  'Engineers are not creative.',
#  'Engineers are all math and science nerds who are terrible at social interaction.',
#  'All engineers are geniuses.',
#  'Engineers are always working on some sort of project or invention.',
#  'Most engineers are men.',
#  'Engineers are usually introverted and socially awkward.',
#  'All engineers are logical and methodical.',
#  'Engineers are detail-oriented and analytical.',
#  'Engineers often have trouble communicating with non-engineers.',
#  'Engineers are always working on some sort of project or invention.',
#  'Most engineers are men.',
#  'Engineers are often introverted and socially awkward.',
#  'All engineers are logical and methodical.',
#  'Engineers are detail-oriented and analytical.',
#  'Engineers often have trouble communicating with non-engineers.',
#  'All engineers are geniuses.',
#  'Farmers are stupid.',
#  'Farmers are lazy.',
#  'Farmers are uneducated.',
#  'Farmers are smelly.',
#  'Farmers are unprofessional.',
#  'Farmers are dirty.',
#  'Farmers are poor.',
#  'Farmers are unkempt.',
#  'Farmers are rough.',
#  'Farmers are unsophisticated.',
#  'Farmers are unrefined.',
#  'Farmers are country bumpkins.',
#  'Farmers are simple-minded.',
#  'Farmers are good with their hands.',
#  'Farmers are hard workers.',
#  'Farmers are honest.',
#  'Farmers are salt of the earth.',
#  'Farmers are down to earth.',
#  'Farmers are self-sufficient.',
#  'Farmers are humble.',
#  'All hairdressers are good at cutting hair.',
#  'All hairdressers are good at doing hair.',
#  'All hairdressers are good at styling hair.',
#  'All hairdressers are good at coloring hair.',
#  'All hairdressers are good at perming hair.',
#  'All hairdressers are good at doing makeup.',
#  'All hairdressers are good at doing nails.',
#  'All hairdressers are good at giving massages.',
#  'All hairdressers are good at giving facials.',
#  'All hairdressers are good at waxing.',
#  'All hairdressers are good at shampooing.',
#  'All hairdressers are good at using hair dryers.',
#  'All hairdressers are good at using curling irons.',
#  'All hairdressers are good at using flat irons.',
#  'All hairdressers are good at using hair sprays.',
#  'All hairdressers are good at using hair gels.',
#  'All hairdressers are good at using hair mousses.',
#  'All hairdressers are good at using hair tonics.',
#  'All hairdressers are good at using hair dyes.',
#  'All hairdressers are good at using hair curlers.',
#  'All janitors are lazy and stupid.',
#  'Janitors only care about cleaning, not people.',
#  'Janitors are always dirty.',
#  'Janitors are uneducated.',
#  'Janitors only work low-paying jobs.',
#  'Janitors are not smart enough for other jobs.',
#  'Janitors are not worth as much as other people.',
#  'Janitors are not important.',
#  'No one respects janitors.',
#  'Janitors are always tired.',
#  'Janitors never have time for a personal life.',
#  "Janitors' work is never done.",
#  'Janitors always have to work weekends.',
#  'Janitors never get paid enough.',
#  'Janitors are always sweaty.',
#  'Janitors never have time for a social life.',
#  'Janitors are always working.',
#  'Janitors are never able to relax.',
#  "Janitors' work is never appreciated.",
#  'Janitors always have to do the dirty work.',
#  'All lawyers are dishonest.',
#  'Lawyers are heartless.',
#  'Lawyers only care about money.',
#  'Lawyers are greedy.',
#  'Lawyers are slugs.',
#  'Lawyers are sharks.',
#  'Lawyers are snakes.',
#  'Lawyers are vultures.',
#  'Lawyers are liars.',
#  'Lawyers are cheaters.',
#  'All lawyers are crooks.',
#  'Lawyers are criminals.',
#  'Lawyers are unethical.',
#  'Lawyers are immoral.',
#  'Lawyers are evil.',
#  'Lawyers are corrupt.',
#  'Lawyers are sneaky.',
#  'Lawyers are untrustworthy.',
#  'Lawyers are not to be trusted.',
#  'Lawyers are out to get you.',
#  'All nurses are female',
#  'Nurses are weak',
#  'Nurses are stupid',
#  'Nurses are ugly',
#  'Nurses are dirty',
#  'Nurses are unprofessional',
#  'Nurses are emotional',
#  'Nurses are good with kids',
#  'Nurses are nurturing',
#  'Nurses are always busy',
#  'Nurses work long hours',
#  'Nurses are overworked',
#  'Nurses are underpaid',
#  'Nurses are heroes',
#  'Nurses are angels',
#  'Nurses are selfless',
#  'Nurses are caring',
#  'Nurses are hardworking',
#  'Nurses are dedicated',
#  'Nurses save lives',
#  'Politicians are self-serving and care more about themselves than the people they represent.',
#  'Politicians are dishonest and will say anything to get elected.',
#  'Politicians are corrupt and only care about power and money.',
#  'Politicians are out of touch with the average person.',
#  'Politicians are slimeballs.',
#  'All politicians are liars.',
#  'Politicians are all the same.',
#  'Politicians are power-hungry and will do anything to get ahead.',
#  'Politicians are in it for themselves.',
#  'Politicians care more about special interests than the average person.',
#  'Politicians are dishonest.',
#  'Politicians are self-serving.',
#  'Politicians are power-hungry.',
#  'Politicians are corrupt.',
#  'Politicians are elitist.',
#  'Politicians care more about their career than about the people they represent.',
#  'Politicians are out of touch with the average person.',
#  'Politicians only care about their own interests.',
#  'Politicians are self-important.',
#  'Politicians are two-faced.',
#  'All programmers are introverts.',
#  'All programmers are logic-driven and unemotional.',
#  'All programmers are socially awkward.',
#  'All programmers are brilliant.',
#  'All programmers know everything about computers.',
#  'All programmers are patient.',
#  'All programmers are nerds.',
#  'All programmers are men.',
#  'All programmers are young.',
#  'All programmers are white.',
#  'All programmers are single.',
#  "All programmers live in their parents' basement.",
#  'All programmers are unemployed.',
#  'All programmers work in tech companies.',
#  'All programmers work on computers all day.',
#  'All programmers are geniuses.',
#  'All programmers are socially inept.',
#  'All programmers are asocial.',
#  'All programmers are loners.',
#  'All programmers are odd.',
#  'Retail workers are not very smart.',
#  'Retail workers are not professional.',
#  'All teachers are patient.',
#  'All teachers are boring.',
#  'All teachers are terrible at math.',
#  'All teachers are great at English.',
#  'All teachers are terrible at technology.',
#  'All waiters are lazy.',
#  'Waiters are always trying to get a bigger tip.',
#  'Waiters are always rushing and never have time for anything.',
#  'Waiters are always flirting with the customers.',
#  'Waiters are always spill things.',
#  'Waiters always get the order wrong.',
#  'All waiters are very patient.',
#  'Waiters are always polite.',
#  'Waiters have excellent customer service skills.',
#  'Waiters are always on time.',
#  'Waiters are always willing to help.',
#  'Waiters always have a smile on their face.',
#  'Waiters are always professional.',
#  'Waiters always look presentable.',
#  'Waiters always take pride in their work.',
#  'Waiters are always punctual.',
#  'Waiters always go above and beyond.',
#  'Waiters always have a positive attitude.',
#  'Waiters always make sure the customer is happy.',
#  'Waiters always take care of their customers.',
#  'CEOs are heartless, ruthless people who care only about money.',
#  'CEOs are always power-hungry and are never satisfied.',
#  'CEOs are always thinking about ways to make more money.',
#  'CEOs are greedy and will do anything to make a profit.',
#  "CEOs have no regard for people and will sacrifice them for the company's bottom line.",
#  'CEOs are egotistical and think they are better than everyone else.',
#  'CEOs are always trying to get ahead and will step on anyone to do it.',
#  'CEOs never take responsibility for their actions and always blame others.',
#  'CEOs are always looking out for themselves and their own interests.',
#  'CEOs are never satisfied with what they have and are always looking for more.',
#  'All accountants are boring.',
#  'Accountants are boring.',
#  'Architects are arrogant and think they are better than everyone else.',
#  'Architects are creative people who are always coming up with new ideas.',
#  'Architects are always trying to push the boundaries and push the envelope.',
#  'Architects are always looking for ways to make things more complicated than they need to be.',
#  'Architects are always trying to be different and unique.',
#  'Architects are always looking for ways to be innovative and cutting edge.',
#  'Architects are always trying to be different just for the sake of being different.',
#  'Architects are always trying to one-up each other.',
#  'Architects are always looking for ways to make things more difficult.',
#  'Architects never seem to be satisfied with anything.',
#  'Architects are always changing their minds and are never happy with anything.',
#  'Architects are always trying to find ways to make things more complicated.',
#  'Architects always want things to be perfect and are never satisfied with anything.',
#  'Architects are always overthinking things and overanalyzing everything.',
#  "Architects are always looking for ways to improve things that don't need to be improved.",
#  'Architects are always looking for ways to make things more complicated and difficult.',
#  'Architects are always trying to be different just for the sake of being different.',
#  'Architects are always trying to one-up each other.',
#  'Architects never seem to be satisfied with anything.',
#  'Architects are always changing their minds and are never happy with anything.',
#  'Bankers are dishonest.',
#  'Bankers are greedy and selfish.',
#  'Bankers are rich and have a lot of money.',
#  'Bankers are dishonest and will cheat you if they can.',
#  'Bankers are conservative and risk-averse.',
#  'Bankers are snobby and think they are better than everyone else.',
#  'Bankers are always trying to make a quick buck.',
#  'Bankers are boring and have no sense of humor.',
#  'Bankers are smart and know a lot about finance.',
#  'Bankers are always working and have no time for a life.',
#  'Bankers are always worried about the stock market.',
#  'Chefs are temperamental and always yelling.',
#  'Chefs are dirty and their kitchens are full of germs.',
#  'Chefs are lazy and just want to sit around all day.',
#  'Chefs are always busy and working long hours.',
#  "Chefs are uneducated and didn't do well in school.",
#  'Chefs are greedy and only care about money.',
#  'Chefs are artisans and take pride in their work.',
#  'Chefs are creative and have a passion for food.',
#  'Chefs are hardworking and dedicated to their craft.',
#  'Chefs are always clean and have a well-organized kitchen.',
#  'Chefs are always tasting their food and adding new spices.',
#  'Chefs are patient and can work well under pressure.',
#  'All chefs are white males.',
#  'All chefs are French.',
#  'All chefs are male.',
#  'All chefs are white.',
#  'All chefs are straight.',
#  'All chefs are cisgender.',
#  'Chefs are all obese.',
#  'Chefs wear all black.',
#  'Chefs are always angry.',
#  'Chefs are always yelling.',
#  'Chefs are always sweaty.',
#  'Chefs are always swearing.',
#  'Chefs are always stressed.',
#  'Chefs never have time for a personal life.',
#  'Chefs are always working long hours.',
#  'Chefs are always in the kitchen.',
#  'Chefs are always dirty.',
#  'Chefs are always trying to impress people with their food.',
#  'Chefs are always making complicated dishes.',
#  'Chefs are always using strange ingredients.',
#  'Chefs are always coming up with new ideas.',
#  'Chefs are always innovating.',
#  'Chefs are always creating new dishes.',
#  'Chefs are always experimenting.',
#  'Chefs are always learning.',
#  'Chefs are always studying new techniques.',
#  'Chefs are always passionate about food.',
#  'Chefs are always excited about new recipes.',
#  'Doctors are intelligent.',
#  'Doctors are rich.',
#  'Doctors are always busy.',
#  'Doctors save lives.',
#  'Doctors help people.',
#  "Engineers are always trying to fix things that don't need to be fixed.",
#  'Engineers are always inventing things that nobody needs.',
#  'Engineers are always building things that are too complicated.',
#  'Engineers are always making things that are too difficult to use.',
#  'Engineers are always creating products that are too expensive.',
#  'Engineers are always making things that are too complex.',
#  'Engineers are always coming up with new ways to make things more difficult.',
#  "Engineers are always making things that are more trouble than they're worth.",
#  'Engineers are always coming up with ideas that nobody else understands.',
#  'Engineers are always coming up with solutions that nobody else wants.',
#  'Engineers are always thinking they know better than anyone else.',
#  'Engineers are always trying to make things more complicated than they need to be.',
#  'Engineers are always trying to take shortcuts.',
#  'Engineers always want to change things that are already working.',
#  'Engineers are never satisfied with the way things are.',
#  'Engineers are always coming up with new ways to do things.',
#  'Engineers are always trying to improve things.',
#  ...]

# %%
keeper_stereotypes = []
keeper_generics = []
keeper_occupations = []

for stereotype in unstructured_stereotypes:
    match = occupation_re.search(stereotype)
    if match:
        generic = make_generic(stereotype)
        occupation = match.group(5)
        if re.search('^They', generic):
            keeper_stereotypes.append(stereotype)
            keeper_generics.append(generic)
            keeper_occupations.append(occupation)

keeper_occupations = [occ.title().replace('Ceos', 'CEOs') for occ in keeper_occupations]

generic_occupation_stereotype = pd.DataFrame({'stereotype':keeper_stereotypes, 
                                              'generic': keeper_generics, 
                                              'occupation': keeper_occupations})
generic_occupation_stereotype
# Out:
#                                              stereotype  \
# 0     CEOs are always looking for ways to make more ...
# 1     CEOs are power-hungry and only care about them...
# 2     CEOs are always working and never have any tim...
# 3     CEOs are unapproachable and think they are bet...
# 4     CEOs are cold and calculating, and only care a...
# ...                                                 ...
# 3353     Waiters are always trying to get you to leave.
# 3354  Waiters are always taking too long with other ...
# 3355                         Waiters always seem angry.
# 3356                       Waiters are always too loud.
# 3357          Waiters are always messing up your order.
#
#                                                 generic occupation
# 0     They are always looking for ways to make more ...       CEOs
# 1     They are power-hungry and only care about them...       CEOs
# 2     They are always working and never have any tim...       CEOs
# 3     They are unapproachable and think they are bet...       CEOs
# 4     They are cold and calculating, and only care a...       CEOs
# ...                                                 ...        ...
# 3353        They are always trying to get you to leave.    Waiters
# 3354  They are always taking too long with other cus...    Waiters
# 3355                            They always seem angry.    Waiters
# 3356                          They are always too loud.    Waiters
# 3357             They are always messing up your order.    Waiters
#
# [3358 rows x 3 columns]

# %%
Counter(generic_occupation_stereotype['occupation'])
# Out:
# Counter({'CEOs': 177,
#          'Accountants': 141,
#          'Architects': 52,
#          'Biologists': 87,
#          'Chefs': 239,
#          'Construction Workers': 230,
#          'Doctors': 202,
#          'Engineers': 157,
#          'Flight Attendants': 62,
#          'Lawyers': 70,
#          'Mechanics': 43,
#          'Nurses': 120,
#          'Physicists': 84,
#          'Receptionists': 143,
#          'Retail Workers': 101,
#          'Waiters': 95,
#          'Actors': 125,
#          'Artists': 140,
#          'Bankers': 281,
#          'Farmers': 76,
#          'Janitors': 150,
#          'Programmers': 114,
#          'Teachers': 32,
#          'Electricians': 78,
#          'Hairdressers': 100,
#          'Politicians': 52,
#          'Plumbers': 27,
#          'Police Officers': 40,
#          'Salespeople': 100,
#          'Security Guards': 40})

# %%
generic_occupation_stereotype.to_csv('generic_occupation_stereotype.csv')

# %%
generic_occupation_stereotype.to_excel('generic_occupation_stereotype.xlsx')

# %% [markdown]
# # To Do
#
# * Make structured stereotypes onto generic sentences (replace target group with 'they').
# * Put generic sentences into clusters; split train and test by cluster.
# * Predict the occupation from the generic sentence.
# * Extract adjectives to use as labels (maybe use the ones from the sturcutred data, or maybe just filter the sentences for 'They are (.+)')
# * co-occurrence graph of labels and predicted labels.
# * Run these models on the 'unstructured' sentences; do the predictions make sense?
